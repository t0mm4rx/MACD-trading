# %%
import ccxt
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
creds = json.loads(open('../creds.json', 'r').read())

# %%
exchange = ccxt.binance(creds['binance'])
# exchange = ccxt.phemex(creds['phemex'])

# %%
exchange.rateLimit
# Out:
# 500

# %%
exchange.enableRateLimit = True

# %% [markdown]
# # Data downloading

# %% [markdown]
# ## We fetch the last BTC tickers from Binance

# %%
from datetime import timezone 
import datetime
dt = datetime.datetime.now()   
utc_time = dt.replace(tzinfo = timezone.utc) 
utc_timestamp = utc_time.timestamp() 
  
timestamp = utc_timestamp
# timestamp *= 1000

# %%
timestamp
# Out:
# 1615475817.835866

# %%
candles = np.array(exchange.fetch_ohlcv("BTC/USDT", '5m'))
n = candles.shape[0]

# %%
candles
# Out:
# array([[1.61532240e+12, 5.45662000e+04, 5.45662100e+04, 5.43681800e+04,
#         5.44375100e+04, 2.15603279e+02],
#        [1.61532270e+12, 5.44375200e+04, 5.44770000e+04, 5.43100600e+04,
#         5.43655000e+04, 1.27617059e+02],
#        [1.61532300e+12, 5.43655000e+04, 5.44395500e+04, 5.42640300e+04,
#         5.44306700e+04, 1.12428691e+02],
#        ...,
#        [1.61547150e+12, 5.70389000e+04, 5.71500000e+04, 5.70100000e+04,
#         5.70686500e+04, 4.12203183e+02],
#        [1.61547180e+12, 5.70686600e+04, 5.71778400e+04, 5.69877200e+04,
#         5.71747300e+04, 3.49911486e+02],
#        [1.61547210e+12, 5.71747300e+04, 5.72385000e+04, 5.70668200e+04,
#         5.70855800e+04, 2.27702957e+02]])

# %% [markdown]
# ## Download historical data

# %%
start = exchange.parse8601('2020-01-01T00:00:00')
time_res = '1h'

candles = None
for _ in range(25):
    print("start:", int(start))
    a = np.array(exchange.fetch_ohlcv("BTC/USDT", time_res, int(start)))
    if (candles is None):
        candles = a
    else:
        candles = np.vstack([candles, a])
    start = a[-1][0]
    time.sleep(1)
# Out:
# start: 1577836800000
# start: 1579633200000
# start: 1581433200000
# start: 1583247600000
# start: 1585047600000
# start: 1586844000000
# start: 1588647600000
# start: 1590444000000
# start: 1592240400000
# start: 1594047600000
# start: 1595844000000
# start: 1597640400000
# start: 1599436800000
# start: 1601233200000
# start: 1603029600000
# start: 1604826000000
# start: 1606622400000
# start: 1608422400000
# start: 1610233200000
# start: 1612029600000
# start: 1613829600000
# start: 1615478400000
# start: 1615478400000
# start: 1615478400000
# start: 1615478400000

# %%
candles.shape
# Out:
# (10462, 6)

# %%
plt.plot(candles[:, 0])
plt.show()

# %%
data = pd.DataFrame()
data['timestamp'] = candles[:, 0]
data['date'] = pd.to_datetime(data['timestamp'] * 1000000)
data['open'] = candles[:, 1]
data['high'] = candles[:, 2]
data['low'] = candles[:, 3]
data['close'] = candles[:, 4]
data['volume'] = candles[:, 5]

# %%
print(data.iloc[0]['date'])
print(data.iloc[-1]['date'])
# Out:
# 2020-01-01 00:00:00
# 2021-03-11 16:00:00

# %%
plt.plot(data['date'], data['close'])
plt.show()

# %% [markdown]
# # Signals creation

# %% [markdown]
# ## MACD calculation

# %%
EWM1 = 12
EWM2 = 26
MACD = 18

ewm1 = data['close'].ewm(span=EWM1, adjust=False).mean()
ewm2 = data['close'].ewm(span=EWM2, adjust=False).mean()
macd = ewm1 - ewm2
macd9 = macd.ewm(span=MACD, adjust=False).mean()
data['macd'] = macd
data['macd2'] = macd9

# %% [markdown]
# ## MACD derivative

# %%
data['macd_der'] = data['macd'] - data['macd'].shift(1)

# %% [markdown]
# ## MACD crossovers calculations

# %%
macd2_shifted = data['macd2'].shift(1)
macd_shifted = data['macd'].shift(1)

crossovers_buy = (macd_shifted < macd2_shifted) & (data['macd'] >= data['macd2'])
data['crossover_buy'] = crossovers_buy

crossovers_sell = (macd_shifted > macd2_shifted) & (data['macd'] <= data['macd2'])
data['crossover_sell'] = crossovers_sell

# macd_der_sign = data['macd_der'] > 0
# crossovers_sell2 = (macd_der_sign != macd_der_sign.shift(1))
# data['crossover_sell'] = crossovers_sell2

# %%
data
# Out:
#           timestamp                date      open      high       low  \
# 0      1.577837e+12 2020-01-01 00:00:00   7195.24   7196.25   7175.46
# 1      1.577840e+12 2020-01-01 01:00:00   7176.47   7230.00   7175.71
# 2      1.577844e+12 2020-01-01 02:00:00   7215.52   7244.87   7211.41
# 3      1.577848e+12 2020-01-01 03:00:00   7242.66   7245.00   7220.00
# 4      1.577851e+12 2020-01-01 04:00:00   7225.00   7230.00   7215.03
# ...             ...                 ...       ...       ...       ...
# 10457  1.615478e+12 2021-03-11 16:00:00  56347.19  56906.00  56340.06
# 10458  1.615478e+12 2021-03-11 16:00:00  56347.19  56906.00  56340.06
# 10459  1.615478e+12 2021-03-11 16:00:00  56347.19  56906.00  56340.06
# 10460  1.615478e+12 2021-03-11 16:00:00  56347.19  56906.00  56340.06
# 10461  1.615478e+12 2021-03-11 16:00:00  56347.19  56906.00  56340.06
#
#           close       volume        macd       macd2   macd_der  \
# 0       7177.02   511.814901    0.000000    0.000000        NaN
# 1       7216.27   883.052603    3.131054    0.250484   3.131054
# 2       7242.85   655.156809    7.668820    0.843951   4.537765
# 3       7225.01   783.724867    9.713521    1.553517   2.044701
# 4       7217.27   467.812578   10.587364    2.276225   0.873843
# ...         ...          ...         ...         ...        ...
# 10457  56888.17  2034.679458  312.792546  318.701355  46.233787
# 10458  56896.10  2035.308554  346.083603  320.891935  33.291057
# 10459  56894.88  2035.880070  368.125046  324.670583  22.041443
# 10460  56898.99  2036.130817  381.526688  329.219072  13.401643
# 10461  56905.99  2037.705163  388.237073  333.940512   6.710385
#
#        crossover_buy  crossover_sell
# 0              False           False
# 1              False           False
# 2              False           False
# 3              False           False
# 4              False           False
# ...              ...             ...
# 10457          False           False
# 10458           True           False
# 10459          False           False
# 10460          False           False
# 10461          False           False
#
# [10462 rows x 12 columns]

# %% [markdown]
# # Plotting

# %%
import matplotlib.dates as mdates

def split_data(start, end):
    i1 = int(start / 100 * data.shape[0])
    i2 = int(end / 100 * data.shape[0])
    return data.iloc[i1:i2]

def plot(start, end):
    graph_data = split_data(start, end)
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(20, 15))
    ax1.plot(graph_data['date'], graph_data['close'])
    ax2.plot(graph_data['date'], graph_data['macd'])
    ax2.plot(graph_data['date'], graph_data['macd2'])
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d/%m/%y %H:%M'))

    for index, row in graph_data.iterrows():
        if (row['crossover_buy']):
            ax2.scatter(row['date'], row['macd'], color='b')
            ax1.scatter(row['date'], row['close'], color='b')
        if (row['crossover_sell']):
            ax2.scatter(row['date'], row['macd'], color='r')
            ax1.scatter(row['date'], row['close'], color='r')

    plt.show()

# %%
plot(70, 75)

# %% [markdown]
# # Backtest

# %%
def backtest(start, end):
    profits = []
    taker_fee = 0.1
    spread = 20

    test_data = split_data(start, end)
    
    last_buy = None
    for index, row in test_data.iterrows():
        if (row['crossover_buy'] and not last_buy):
            last_buy = row['close'] + spread
        if (row['crossover_sell'] and last_buy):
            price = row['close']
            variation = (price - last_buy) / last_buy * 100
            profits.append(variation - taker_fee)
            last_buy = None
    profits = np.array(profits)
    volatility = test_data['close'].std()
    return (profits, profits.sum(), volatility)

# %%
splits = 10
batch_size = 100 / splits

pnl_total = []
trades = 0

x = []
y = []

for i in range(splits):
    start = batch_size * i
    end = batch_size * i + batch_size
    pnl, total, std = backtest(start, end)
    print("{:3.0f}%-{:3.0f}% -> profit {:.2f}%".format(start, end, total))
    pnl_total += list(pnl)
    trades += pnl.shape[0]
    
    x += [std]
    y += [total]

plt.hist(pnl_total, bins=15)
plt.show()

plt.scatter(x, y)
plt.show()

print("Total: {:.2f}% for {} trades".format(np.array(pnl_total).sum(), trades))
# Out:
#   0%- 10% -> profit 10.08%
#  10%- 20% -> profit 1.99%
#  20%- 30% -> profit 24.75%
#  30%- 40% -> profit -0.14%
#  40%- 50% -> profit -1.30%
#  50%- 60% -> profit -15.88%
#  60%- 70% -> profit -4.57%
#  70%- 80% -> profit 24.57%
#  80%- 90% -> profit 37.35%
#  90%-100% -> profit 57.34%
# Total: 134.17% for 266 trades

# %% [markdown]
# # Strategy testing

# %%
good_splits = [
    [50.5, 51.5],
    [54, 54.7],
]

# %%
plot(2, 4.9)

# %%
plot(5, 10)

# %% [markdown]
# # Fetch balance

# %%
balance = exchange.fetch_balance()

# %%
balance['USDT']['total']
# Out:
# 100.0

# %%
exchange.fetch_open_orders("BTC/USDT")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     587             self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 588             response.raise_for_status()
#     589
#
# /usr/local/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.binance.com/api/v3/openOrders?timestamp=1615243493713&recvWindow=5000&symbol=BTCUSDT&signature=83291e610a9a6387fb12df911197ff42403a3f9554e218fb042b79ca3760ac5a
#
# During handling of the above exception, another exception occurred:
#
# InvalidNonce                              Traceback (most recent call last)
# <ipython-input-445-3223893f0c34> in <module>
# ----> 1 exchange.fetch_open_orders("BTC/USDT")
#
# /usr/local/lib/python3.8/site-packages/ccxt/binance.py in fetch_open_orders(self, symbol, since, limit, params)
#    1775         elif type == 'margin':
#    1776             method = 'sapiGetMarginOpenOrders'
# -> 1777         response = getattr(self, method)(self.extend(request, query))
#    1778         return self.parse_orders(response, market, since, limit)
#    1779
#
# /usr/local/lib/python3.8/site-packages/ccxt/base/exchange.py in inner(_self, params)
#     463                             if params is not None:
#     464                                 inner_kwargs['params'] = params
# --> 465                             return entry(_self, **inner_kwargs)
#     466                         return inner
#     467                     to_bind = partialer()
#
# /usr/local/lib/python3.8/site-packages/ccxt/binance.py in request(self, path, api, method, params, headers, body)
#    2451
#    2452     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# -> 2453         response = self.fetch2(path, api, method, params, headers, body)
#    2454         # a workaround for {"code":-2015,"msg":"Invalid API-key, IP, or permissions for action."}
#    2455         if (api == 'private') or (api == 'wapi'):
#
# /usr/local/lib/python3.8/site-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body)
#     484         self.lastRestRequestTimestamp = self.milliseconds()
#     485         request = self.sign(path, api, method, params, headers, body)
# --> 486         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     487
#     488     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# /usr/local/lib/python3.8/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     602         except HTTPError as e:
#     603             details = ' '.join([self.id, method, url])
# --> 604             self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     605             self.handle_http_status_code(http_status_code, http_status_text, url, method, http_response)
#     606             raise ExchangeError(details) from e
#
# /usr/local/lib/python3.8/site-packages/ccxt/binance.py in handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    2445                 raise DDoSProtection(self.id + ' temporary banned: ' + body)
#    2446             feedback = self.id + ' ' + body
# -> 2447             self.throw_exactly_matched_exception(self.exceptions, error, feedback)
#    2448             raise ExchangeError(feedback)
#    2449         if not success:
#
# /usr/local/lib/python3.8/site-packages/ccxt/base/exchange.py in throw_exactly_matched_exception(self, exact, string, message)
#     502     def throw_exactly_matched_exception(self, exact, string, message):
#     503         if string in exact:
# --> 504             raise exact[string](message)
#     505
#     506     def throw_broadly_matched_exception(self, broad, string, message):
#
# InvalidNonce: binance {"code":-1021,"msg":"Timestamp for this request is outside of the recvWindow."}

# %% [markdown]
# # Tweeting

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler(creds['twitter']['apiKey'], 
    creds['twitter']['secret'])
auth.set_access_token(creds['twitter']['accessToken'], 
    creds['twitter']['accessTokenSecret'])

api = tweepy.API(auth)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %%
api.update_status("Hello! This tweet is sent from a #Python notebook :)")
# Out:
# Status(_api=<tweepy.api.API object at 0x1187a88b0>, _json={'created_at': 'Mon Mar 08 22:03:27 +0000 2021', 'id': 1369046127404810244, 'id_str': '1369046127404810244', 'text': 'Hello! This tweet is sent from a #Python notebook :)', 'truncated': False, 'entities': {'hashtags': [{'text': 'Python', 'indices': [33, 40]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1369041402995281922, 'id_str': '1369041402995281922', 'name': 'MACD crypto bot', 'screen_name': 'bot_macd', 'location': '', 'description': "I'm a bot.\nI buy every MACD crossover on $BTC.\nI tweet my trades and current balance.\nMy father is @AirM4rx.\n#btc", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Mon Mar 08 21:44:56 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1369041747997786120/hTF_T0u4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369041747997786120/hTF_T0u4_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 3, 8, 22, 3, 27), id=1369046127404810244, id_str='1369046127404810244', text='Hello! This tweet is sent from a #Python notebook :)', truncated=False, entities={'hashtags': [{'text': 'Python', 'indices': [33, 40]}], 'symbols': [], 'user_mentions': [], 'urls': []}, source='', source_url=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1187a88b0>, _json={'id': 1369041402995281922, 'id_str': '1369041402995281922', 'name': 'MACD crypto bot', 'screen_name': 'bot_macd', 'location': '', 'description': "I'm a bot.\nI buy every MACD crossover on $BTC.\nI tweet my trades and current balance.\nMy father is @AirM4rx.\n#btc", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 1, 'listed_count': 0, 'created_at': 'Mon Mar 08 21:44:56 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1369041747997786120/hTF_T0u4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369041747997786120/hTF_T0u4_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False ...

# %% [markdown]
# Tweet with matplotlib visualization

# %%
# Random matplotlib graph
x = list(range(10))
y = [0, -1, -1.2, -0.5, 1.3, 1.4, 1.3, 2.2, 2.8, 3.4]

plt.plot(x, y)
plt.savefig("/tmp/vis.png")

# %%
media = api.media_upload("/tmp/vis.png")
tweet = "Testing to tweet a #matplotlib graph!!!"
post_result = api.update_status(status=tweet, media_ids=[media.media_id])
